# %%
import sys
sys.path.append('..')
import warnings
import panel as pn
pn.extension()
warnings.filterwarnings("ignore")
from stelardataprofiler import (
    profile_hierarchical,
    write_to_json
)

# %% [markdown]
# ## Run Profiler

# %%
json_file_path = '../datasets/json/json_example.json'
profile_dict = profile_hierarchical(my_file_path=json_file_path)
profile_dict
# Out:
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...  (with 19 processes)
# 100%|██████████| 31/31 [00:00<00:00, 5238.66it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...  (with 4 processes)
# 100%|██████████| 31/31 [00:00<00:00, 81.63it/s]
# {'analysis': {'title': 'Profiling Report',
#   'date_start': '2023-05-05 19:11:43.519066',
#   'date_end': '2023-05-05 19:11:45.428873',
#   'duration': '0:00:01.909807',
#   'filenames': ['../datasets/json/json_example.json']},
#  'table': {'profiler_type': 'Hierarchical',
#   'byte_size': 38020,
#   'num_records': 31,
#   'depth_distribution': {'count': 31.0,
#    'min': 0.0,
#    'max': 3.0,
#    'average': 0.967741935483871,
#    'stddev': 0.8360171835451684,
#    'median': 1.0,
#    'kurtosis': 0.55545725362171,
#    'skewness': 0.7945974021863222,
#    'variance': 0.6989247311827957,
#    'percentile10': 0.0,
#    'percentile25': 0.0,
#    'percentile75': 1.0,
# ...

# %% [markdown]
# ## Output of the Profiler

# %% [markdown]
# ### JSON

# %%
write_to_json(profile_dict, "../output/json/hierarchical_profile.json")
